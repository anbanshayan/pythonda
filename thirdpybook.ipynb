# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def greet(self):
        print("Good morning !!",self.name)

p1 = Person("Kanban",56)
p1.greet()
# Out:
# Good morning !! Kanban

# %%
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

    def displayCar(self):
        print(self.brand,self.model)

c1 = Car("Toyota","Raize")
c1.displayCar()
# Out:
# Toyota Raize

# %%
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

    def __str__(self):
        return f"{self.brand}_{self.model}"

c1 = Car("Toyota","Raize")
print(c1)
# Out:
# Toyota_Raize

# %%
class Circle:
    def __init__(self,radius):
        self.radius = radius

    def area(self):
        return (22/7)*self.radius**2
    
c = Circle(7)
c.area()
# Out:
# 154.0

# %%
class Laptop:
    def __init__(self,brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price

    def apply_discount(self):
        return self.price*0.85
    
lap = Laptop("HP","Razon",50000)
lap.apply_discount()
# Out:
# 42500.0

# %%
class Book:
    def __init__(self,title,author):
        self.title = title
        self.author = author
    
    def __str__(self):
        return f"The Book {self.title} is written by {self.author}"
    
book1 = Book("The Vendor of Sweets","R.K.Narayan")
print(book1)
# Out:
# The Book The Vendor of Sweets is written by R.K.Narayan

# %%
class Subject:
    def __init__(self,code,name):
        self.code = code
        self.name = name

    def __str__(self):
        return f"{self.code},{self.name}"
    
c1=Subject("IS1102","Computer Systems")
print(c1)
# Out:
# IS1102,Computer Systems
