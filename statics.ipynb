# %%
#Statistics
import numpy as np

static = np.array([[1,2,3],[4,5,6]])
static
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#finding minimum
np.min(static)
# Out:
# 6

# %%
#finding maximum
np.max(static)
# Out:
# 6

# %%
#finding min ro vice
np.max(static,axis=0)
# Out:
# array([4, 5, 6])
